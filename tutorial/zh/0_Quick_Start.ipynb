# %% [markdown]
# # 安装FLGo

# %% [markdown]
# 在使用FLGo之前，需要自行安装以下基本的库：numpy，pytorch，torchvision，scipy，numpy，matplotlib，prettytable。这些库对版本没有特殊要，网上配置教程较多，这里不再赘述。
#
# 在FLGo中还会用到一些额外的第三方库，这些库主要针对特定功能或算法的实现，比如cvxopt，pynvml等，可以等用到的时候再进行安装。由于近期刚刚把原来的github仓库封装成包，暂时挂在了test.pypi上，后续完善基础的一些文档和说明后将挂到pypi上。在命令行输入下列命令即可安装FLGo

# %%
# !pip install flgo

# %% [markdown]
# # 运行FLGo

# %%
import flgo
import flgo.benchmark.mnist_classification as mnist
import flgo.algorithm.fedavg as fedavg
import os

# %% [markdown]
# ### 生成联邦任务 \ Generate Federated Task

# %% [markdown]
# 生成mnist的IID划分，人数为100人，代码如下：

# %%
task = './test_mnist'
config = {'benchmark':{'name':'flgo.benchmark.mnist_classification'},'partitioner':{'name': 'IIDPartitioner','para':{'num_clients':100}}}
if not os.path.exists(task): flgo.gen_task(config, task_path = task)

# %% [markdown]
# ### 开始使用fedavg联邦训练 \ Start training with FedAvg

# %% [markdown]
# 使用fedavg训练，参数为5轮，本地训练epoch为1，仅使用0卡训练

# %%
fedavg_runner = flgo.init(task=task, algorithm=fedavg, option={'num_rounds':5, 'num_epochs':1, 'cpu':0})
fedavg_runner.run()
# Out:
# 2024-07-27 16:07:54,669 fflow.py init [line:691] INFO PROCESS ID:	12272
# 2024-07-27 16:07:54,669 fflow.py init [line:692] INFO Initializing devices: cpu will be used for this running.
# 2024-07-27 16:07:54,670 fflow.py init [line:695] INFO BENCHMARK:	flgo.benchmark.mnist_classification
# 2024-07-27 16:07:54,670 fflow.py init [line:696] INFO TASK:			./test_mnist
# 2024-07-27 16:07:54,670 fflow.py init [line:697] INFO MODEL:		flgo.benchmark.mnist_classification.model.cnn
# 2024-07-27 16:07:54,671 fflow.py init [line:698] INFO ALGORITHM:	fedavg
# 2024-07-27 16:07:54,691 fflow.py init [line:737] INFO SCENE:		horizontal FL with 1 <class 'flgo.algorithm.fedbase.BasicServer'>, 100 <class 'flgo.algorithm.fedbase.BasicClient'>
# 2024-07-27 16:07:54,701 fflow.py init [line:754] INFO SIMULATOR:	<class 'flgo.simulator.default_simulator.Simulator'>
# 2024-07-27 16:07:54,703 fflow.py init [line:767] INFO Ready to start.
# 2024-07-27 16:07:54,704 fedbase.py run [line:242] INFO --------------Initial Evaluation--------------
# 2024-07-27 16:07:54,704 simple_logger.py log_once [line:14] INFO Current_time:0
# 2024-07-27 16:08:02,638 simple_logger.py log_once [line:28] INFO test_accuracy                 0.0845
# 2024-07-27 16:08:02,639 simple_logger.py log_once [line:28] INFO test_loss                     2.3038
# 2024-07-27 16:08:02,640 simple_logger.py log_once [line:28] INFO val_accuracy                  0.0772
# 2024-07-27 16:08:02,641 simple_logger.py log_once [line:28] INFO mean_val_accuracy             0.0772
# 2024-07-27 16:08:02,641 simple_logger.py log_once [line:28] INFO std_val_accuracy              0.0365
# 2024-07-27 16:08:02,642 simple_logger.py log_once [line:28] INFO val_loss                      2.3038
# 2024-07-27 16:08:02,643 simple_logger.py log_once [line:28] INFO mean_val_loss                 2.3038
# 2024-07-27 16:08:02,644 simple_logger.py log_once [line:28] INFO std_val_loss                  0.0076
# 2024-07-27 16:08:02,644 fedbase.py run [line:245] INFO Eval Time Cost:               7.9400s
# 2024-07-27 16:08:13,012 fedbase.py run [line:253] INFO --------------Round 1--------------
# 2024-07-27 16:08:13,013 simple_logger.py log_once [line:14] INFO Current_time:1
# 2024-07-27 16:08:20,808 simple_logger.py log_once [line:28] INFO test_accuracy                 0.6535
# 2024-07-27 16:08:20,809 simple_logger.py log_once [line:28] INFO test_loss                     1.5823
# 2024-07-27 16:08:20,810 simple_logger.py log_once [line:28] INFO val_accuracy                  0.6268
# 2024-07-27 16:08:20,811 simple_logger.py log_once [line:28] INFO mean_val_accuracy             0.6268
# 2024-07-27 16:08:20,812 simple_logger.py log_once [line:28] INFO std_val_accuracy              0.0585
# 2024-07-27 16:08:20,813 simple_logger.py log_once [line:28] INFO val_loss                      1.6045
# 2024-07-27 16:08:20,813 simple_logger.py log_once [line:28] INFO mean_val_loss                 1.6045
# 2024-07-27 16:08:20,814 simple_logger.py log_once [line:28] INFO std_val_loss                  0.0596
# 2024-07-27 16:08:20,815 fedbase.py run [line:258] INFO Eval Time Cost:               7.8014s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 fedavg_runner = flgo.init(task=task, algorithm=fedavg, option={'num_rounds':5, 'num_epochs':1, 'cpu':0})
# ----> 2 fedavg_runner.run()
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:250, in BasicServer.run(self)
#     248 self.gv.clock.step()
#     249 # iterate
# --> 250 updated = self.iterate()#进行客户端选择和模型聚合
#     251 # using logger to evaluate the model if the model is updated
#     252 if updated is True or updated is None:
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:299, in BasicServer.iterate(self)
#     297 self.selected_clients = self.sample()#选择客户端
#     298 # training
# --> 299 models = self.communicate(self.selected_clients)['model']#拿到选择的客户端的模型
#     300 # aggregate: pk = 1/K as default where K=len(selected_clients)
#     301 self.model = self.aggregate(models)#对模型进行聚合
#
# File E:\workspace\easyFL\flgo\simulator\base.py:490, in with_dropout.<locals>.communicate_with_dropout(self, selected_clients, mtype, asynchronous)
#     488     self._dropped_selected_clients = [cid for cid,prob in zip(selected_clients, probs_drop) if self.gv.simulator.random_module.rand() <= prob]
#     489     self.gv.simulator.set_client_state(self._dropped_selected_clients, 'dropped')
# --> 490     return communicate(self, [cid for cid in selected_clients if cid not in self._dropped_selected_clients], mtype, asynchronous)
#     491 else:
#     492     return communicate(self, selected_clients, mtype, asynchronous)
#
# File E:\workspace\easyFL\flgo\simulator\base.py:490, in with_dropout.<locals>.communicate_with_dropout(self, selected_clients, mtype, asynchronous)
#     488     self._dropped_selected_clients = [cid for cid,prob in zip(selected_clients, probs_drop) if self.gv.simulator.random_module.rand() <= prob]
#     489     self.gv.simulator.set_client_state(self._dropped_selected_clients, 'dropped')
# --> 490     return communicate(self, [cid for cid in selected_clients if cid not in self._dropped_selected_clients], mtype, asynchronous)
#     491 else:
#     492     return communicate(self, selected_clients, mtype, asynchronous)
#
#     [... skipping similar frames: with_dropout.<locals>.communicate_with_dropout at line 490 (14 times)]
#
# File E:\workspace\easyFL\flgo\simulator\base.py:490, in with_dropout.<locals>.communicate_with_dropout(self, selected_clients, mtype, asynchronous)
#     488     self._dropped_selected_clients = [cid for cid,prob in zip(selected_clients, probs_drop) if self.gv.simulator.random_module.rand() <= prob]
#     489     self.gv.simulator.set_client_state(self._dropped_selected_clients, 'dropped')
# --> 490     return communicate(self, [cid for cid in selected_clients if cid not in self._dropped_selected_clients], mtype, asynchronous)
#     491 else:
#     492     return communicate(self, selected_clients, mtype, asynchronous)
#
# File E:\workspace\easyFL\flgo\simulator\base.py:578, in with_clock.<locals>.communicate_with_clock(self, selected_clients, mtype, asynchronous)
#     576 def communicate_with_clock(self, selected_clients, mtype=0, asynchronous=False):
#     577     self.gv.simulator.update_client_completeness(selected_clients)
# --> 578     res = communicate(self, selected_clients, mtype, asynchronous)
#     579     # If all the selected clients are unavailable, directly return the result without waiting.
#     580     # Else if all the available clients have dropped out and not using asynchronous communication,  waiting for `tolerance_for_latency` time units.
#     581     tolerance_for_latency = self.get_tolerance_for_latency()
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:330, in BasicServer.communicate(self, selected_clients, mtype, asynchronous)
#     328         server_pkg = self.pack(client_id, mtype)#获取服务器端上的模型
#     329         server_pkg['__mtype__'] = mtype
# --> 330         response_from_client_id = self.communicate_with(self.clients[client_id].id, package=server_pkg)#与客户端进行通信，获取客户端上的模型
#     331         packages_received_from_clients.append(response_from_client_id)
#     332 else:
#
# File E:\workspace\easyFL\flgo\simulator\base.py:521, in with_latency.<locals>.delayed_communicate_with(self, target_id, package)
#     519 # Set downloading package sizes for clients for downloading cost estimation
#     520 self.gv.simulator.set_variable(target_id, '__download_package_size',size_of_package(package))
# --> 521 res = communicate_with(self, target_id, package)#res还是服务器模型
#     522 if res is None: res = {}
#     523 # Set uploading package sizes for clients for uploading cost estimation
#
# File E:\workspace\easyFL\flgo\simulator\base.py:521, in with_latency.<locals>.delayed_communicate_with(self, target_id, package)
#     519 # Set downloading package sizes for clients for downloading cost estimation
#     520 self.gv.simulator.set_variable(target_id, '__download_package_size',size_of_package(package))
# --> 521 res = communicate_with(self, target_id, package)#res还是服务器模型
#     522 if res is None: res = {}
#     523 # Set uploading package sizes for clients for uploading cost estimation
#
#     [... skipping similar frames: with_latency.<locals>.delayed_communicate_with at line 521 (14 times)]
#
# File E:\workspace\easyFL\flgo\simulator\base.py:521, in with_latency.<locals>.delayed_communicate_with(self, target_id, package)
#     519 # Set downloading package sizes for clients for downloading cost estimation
#     520 self.gv.simulator.set_variable(target_id, '__download_package_size',size_of_package(package))
# --> 521 res = communicate_with(self, target_id, package)#res还是服务器模型
#     522 if res is None: res = {}
#     523 # Set uploading package sizes for clients for uploading cost estimation
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:376, in BasicServer.communicate_with(self, target_id, package)
#     363 def communicate_with(self, target_id, package={}):
#     364     r"""Communicate with the object under system simulator that simulates the
#     365     network latency. Send the package to target object according to its id,
#     366     and receive the response from it
#    (...)
#     374         will be 'None' if losing connection
#     375     """
# --> 376     return super(BasicServer, self).communicate_with(target_id, package)
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:194, in BasicParty.communicate_with(self, target_id, package)
#     184 def communicate_with(self, target_id, package={}):
#     185     r"""
#     186     Send the package to target object according to its id, and receive the response from it
#     187
#    (...)
#     192         client_package (dict): the reply from the target object and will be 'None' if losing connection
#     193     """
# --> 194     return self.gv.communicator.request(self.id, target_id, package)
#
# File E:\workspace\easyFL\flgo\__init__.py:17, in VirtualCommunicator.request(self, source, target, package)
#      15 def request(self, source, target, package):
#      16     # send package to the target object with `package` and `mtype`, and then listen from it
# ---> 17     return self.objects_map[target].message_handler(package)
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:53, in BasicParty.message_handler(self, package)
#      51 if mtype not in self.actions.keys():
#      52     raise NotImplementedError("There is no action corresponding to message type {}.".format(mtype))
# ---> 53 return self.actions[mtype](package)
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:820, in BasicClient.reply(self, svr_pkg)
#     807 r"""
#     808 Reply a package to the server. The whole local_movielens_recommendation procedure should be defined here.
#     809 The standard form consists of three procedure: unpacking the
#    (...)
#     817     client_pkg (dict): the package to be send to the server
#     818 """
#     819 model = self.unpack(svr_pkg)
# --> 820 self.train(model)
#     821 cpkg = self.pack(model)
#     822 return cpkg
#
# File E:\workspace\easyFL\flgo\simulator\base.py:557, in with_completeness.<locals>.train_with_incomplete_update(self, model, *args, **kwargs)
#     555 old_num_steps = self.num_steps
#     556 self.num_steps = self._working_amount
# --> 557 res = train(self, model, *args, **kwargs)
#     558 self.num_steps = old_num_steps
#     559 return res
#
# File E:\workspace\easyFL\flgo\simulator\base.py:557, in with_completeness.<locals>.train_with_incomplete_update(self, model, *args, **kwargs)
#     555 old_num_steps = self.num_steps
#     556 self.num_steps = self._working_amount
# --> 557 res = train(self, model, *args, **kwargs)
#     558 self.num_steps = old_num_steps
#     559 return res
#
#     [... skipping similar frames: with_completeness.<locals>.train_with_incomplete_update at line 557 (14 times)]
#
# File E:\workspace\easyFL\flgo\simulator\base.py:557, in with_completeness.<locals>.train_with_incomplete_update(self, model, *args, **kwargs)
#     555 old_num_steps = self.num_steps
#     556 self.num_steps = self._working_amount
# --> 557 res = train(self, model, *args, **kwargs)
#     558 self.num_steps = old_num_steps
#     559 return res
#
# File E:\workspace\easyFL\flgo\utils\fmodule.py:935, in with_multi_gpus.<locals>.cal_on_personal_gpu(self, model, *args, **kargs)
#     933 model.to(self.device)
#     934 # calculating
# --> 935 res = func(self, model, *tuple(new_args), **new_kargs)
#     936 # transter to original device
#     937 model.to(origin_device)
#
# File E:\workspace\easyFL\flgo\algorithm\fedbase.py:772, in BasicClient.train(self, model)
#     768 model.train()
#     769 optimizer = self.calculator.get_optimizer(model, lr=self.learning_rate, weight_decay=self.weight_decay,
#     770                                           momentum=self.momentum)
#     771 for iter in range(self.num_steps):
# --> 772     # get a batch of data
#     773     batch_data = self.get_batch_data()
#     774     model.zero_grad()
#
# File D:\Software\anaconda3\envs\easyFL\lib\site-packages\torch\_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File D:\Software\anaconda3\envs\easyFL\lib\site-packages\torch\autograd\__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File D:\Software\anaconda3\envs\easyFL\lib\site-packages\torch\autograd\graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ###  训练结果展示 \ Training Result

# %% [markdown]
# 绘制训练过程中的验证集损失和验证集精度

# %%
import flgo.experiment.analyzer as al
analysis_plan = {
    'Selector':{
        'task': task,
        'header':['fedavg']
    },
    'Painter':{
        'Curve':[
            {'args':{'x': 'communication_round', 'y':'val_loss'}, 'fig_option':{'title':'valid loss on MNIST'}},
            {'args':{'x': 'communication_round', 'y':'val_accuracy'},  'fig_option':{'title':'valid accuracy on MNIST'}},
        ]
    }
}
al.show(analysis_plan)
